# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('TopRichestInWorld.csv')
df
# Out:
#                          Name          NetWorth  Age Country/Territory  \
# 0                   Elon Musk  $219,000,000,000   50     United States
# 1                  Jeff Bezos  $171,000,000,000   58     United States
# 2    Bernard Arnault & family  $158,000,000,000   73            France
# 3                  Bill Gates  $129,000,000,000   66     United States
# 4              Warren Buffett  $118,000,000,000   91     United States
# ..                        ...               ...  ...               ...
# 96           Vladimir Potanin   $17,300,000,000   61            Russia
# 97       Harold Hamm & family   $17,200,000,000   76     United States
# 98               Sun Piaoyang   $17,100,000,000   63             China
# 99         Luo Liguo & family   $17,000,000,000   66             China
# 100                 Peter Woo   $17,000,000,000   75         Hong Kong
#
#                  Source               Industry
# 0         Tesla, SpaceX             Automotive
# ...

# %%
industry = df['Industry'].value_counts()
industry
# Out:
# Industry
# Fashion & Retail         18
# Technology               15
# Finance & Investments    13
# Metals & Mining           9
# Food & Beverage           8
# Automotive                7
# Diversified               6
# Manufacturing             5
# Healthcare                5
# Media & Entertainment     4
# Real Estate               3
# Telecom                   2
# Logistics                 2
# Energy                    2
# Gambling & Casinos        1
# Service                   1
# Name: count, dtype: int64

# %%
industry.index
# Out:
# Index(['Fashion & Retail', 'Technology', 'Finance & Investments',
#        'Metals & Mining', 'Food & Beverage', 'Automotive', 'Diversified',
#        'Manufacturing', 'Healthcare', 'Media & Entertainment', 'Real Estate',
#        'Telecom', 'Logistics', 'Energy', 'Gambling & Casinos', 'Service'],
#       dtype='object', name='Industry')

# %%
plt.pie(x=industry.values, labels=industry.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x1b075566f90>,
# ...
#  [Text(0.9320461635394063, 0.5842002644911028, 'Fashion & Retail'),
#   Text(-0.01710703950300457, 1.099866968864618, 'Technology'),
#   Text(-0.8523428619674444, 0.6953500166485556, 'Finance & Investments'),
#   Text(-1.0999999999999954, -1.0298943258065002e-07, 'Metals & Mining'),
#   Text(-0.9497638199575874, -0.5549312446597071, 'Food & Beverage'),
#   Text(-0.5986245075706607, -0.922848145111526, 'Automotive'),
#   Text(-0.18726779260124032, -1.0839422373236773, 'Diversified'),
#   Text(0.18726803363047703, -1.0839421956821196, 'Manufacturing'),
#   Text(0.5100299960839939, -0.9746124373793726, 'Healthcare'),
#   Text(0.7594621119777382, -0.7957495211876119, 'Media & Entertainment'),
#   Text(0.9134268495401443, -0.6129040630793424, 'Real Estate'),
#   Text(0.9973399133690894, -0.464018423342153, 'Telecom'),
#   Text(1.047214455404698, -0.336662864586283, 'Logistics'),
#   Text(1.080898795145707, -0.20410241216741928, 'Energy'),
# ...

# %%
labels = industry.index[:10]
values = industry.values[:10]

plt.pie(x=values, labels=labels, autopct='%.2f%%', colors=('blue', 'red'))
# Out:
# ([<matplotlib.patches.Wedge at 0x1b075653920>,
# ...
#  [Text(0.8899186877588753, 0.6465637858537406, 'Fashion & Retail'),
#   Text(-0.2287028968371194, 1.0759623529558597, 'Technology'),
#   Text(-1.0199022687445178, 0.4120671816703988, 'Finance & Investments'),
#   Text(-1.0199022012286048, -0.41206734877814155, 'Metals & Mining'),
#   Text(-0.6151120975257726, -0.9119413947603456, 'Food & Beverage'),
#   Text(-0.0767319881291848, -1.09732046458532, 'Automotive'),
#   Text(0.41206739652320884, -1.0199021819383391, 'Diversified'),
#   Text(0.7641243287151949, -0.7912736633210743, 'Manufacturing'),
#   Text(0.9886735260496547, -0.48220810744795956, 'Healthcare'),
#   Text(1.0892949001814978, -0.1530902362614323, 'Media & Entertainment')],
#  [Text(0.4854101933230228, 0.35267115592022213, '20.00%'),
#   Text(-0.12474703463842875, 0.5868885561577416, '16.67%'),
#   Text(-0.5563103284061006, 0.22476391727476294, '14.44%'),
#   Text(-0.556310291579239, -0.22476400842444083, '10.00%'),
# ...

# %%
# scatter plot
pokemon = pd.read_csv('Pokemon.csv', index_col='#')
pokemon
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 1                Bulbasaur    Grass  Poison    318  45      49       49
# 2                  Ivysaur    Grass  Poison    405  60      62       63
# 3                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 719                Diancie     Rock   Fairy    600  50     100      150
# 719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# #
# ...

# %%
pokemon.plot(x='Defense', y='Attack', kind='scatter', color='red')
# Out:
# <Axes: xlabel='Defense', ylabel='Attack'>

# %%
import mplfinance as mpf

# %%
apple = pd.read_csv('AAPL.csv', index_col='date', parse_dates=['date'])
apple
# Out:
#                            Unnamed: 0 symbol    close     high       low  \
# date
# 2015-05-27 00:00:00+00:00           0   AAPL  132.045  132.260  130.0500
# 2015-05-28 00:00:00+00:00           1   AAPL  131.780  131.950  131.1000
# 2015-05-29 00:00:00+00:00           2   AAPL  130.280  131.450  129.9000
# 2015-06-01 00:00:00+00:00           3   AAPL  130.535  131.390  130.0500
# 2015-06-02 00:00:00+00:00           4   AAPL  129.960  130.655  129.3200
# ...                               ...    ...      ...      ...       ...
# 2020-05-18 00:00:00+00:00        1253   AAPL  314.960  316.500  310.3241
# 2020-05-19 00:00:00+00:00        1254   AAPL  313.140  318.520  313.0100
# 2020-05-20 00:00:00+00:00        1255   AAPL  319.230  319.520  316.2000
# 2020-05-21 00:00:00+00:00        1256   AAPL  316.850  320.890  315.8700
# 2020-05-22 00:00:00+00:00        1257   AAPL  318.890  319.230  315.3500
#
#                              open    volume    adjClose     adjHigh  \
# date
# ...

# %%
year = apple.loc['2016-01':'2016-3']
year
# Out:
#                            Unnamed: 0 symbol   close     high     low    open  \
# date
# 2016-01-04 00:00:00+00:00         153   AAPL  105.35  105.368  102.00  102.61
# 2016-01-05 00:00:00+00:00         154   AAPL  102.71  105.850  102.41  105.75
# 2016-01-06 00:00:00+00:00         155   AAPL  100.70  102.370   99.87  100.56
# 2016-01-07 00:00:00+00:00         156   AAPL   96.45  100.130   96.43   98.68
# 2016-01-08 00:00:00+00:00         157   AAPL   96.96   99.110   96.76   98.55
# ...                               ...    ...     ...      ...     ...     ...
# 2016-03-24 00:00:00+00:00         209   AAPL  105.67  106.250  104.89  105.47
# 2016-03-28 00:00:00+00:00         210   AAPL  105.19  106.190  105.06  106.00
# 2016-03-29 00:00:00+00:00         211   AAPL  107.68  107.790  104.88  104.89
# 2016-03-30 00:00:00+00:00         212   AAPL  109.56  110.420  108.60  108.65
# 2016-03-31 00:00:00+00:00         213   AAPL  108.99  109.900  108.88  109.72
#
# ...

# %%
mpf.plot(year, type='candle',style='yahoo', title='Apple', ylabel='Price $', figratio=(3,1), volume=True)

# %%
import bar_chart_race as bcr

# %%
lan = pd.read_csv('languages.csv', index_col='Date', parse_dates=['Date'])
lan.index = lan.index.to_period('m')
lan
# Out:
# C:\Users\being\AppData\Local\Temp\ipykernel_5632\2542180307.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   lan = pd.read_csv('languages.csv', index_col='Date', parse_dates=['Date'])
# C:\Users\being\AppData\Local\Temp\ipykernel_5632\2542180307.py:2: FutureWarning: 'm' is deprecated and will be removed in a future version, please use 'M' instead.
#   lan.index = lan.index.to_period('m')
#          Abap   Ada  C/C++    C#  Cobol  Dart  Delphi/Pascal    Go  Groovy  \
# Date
# 2004-07  0.34  0.36  10.01  4.68   0.42  0.00           2.80  0.00    0.03
# 2004-08  0.35  0.36   9.74  4.96   0.46  0.00           2.65  0.00    0.07
# 2004-09  0.41  0.41   9.59  5.04   0.51  0.00           2.64  0.00    0.08
# 2004-10  0.40  0.38   9.47  5.29   0.53  0.00           2.76  0.00    0.09
# ...

# %%
bcr.bar_chart_race(lan.iloc[:5], n_bars=10, steps_per_period=30, period_length=125, title='Popular Programming Languages', filter_column_colors=True)
# Out:
# C:\Users\being\AppData\Local\Programs\Python\Python312\Lib\site-packages\bar_chart_race\_make_chart.py:889: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_values.iloc[:, 0] = df_values.iloc[:, 0].fillna(method='ffill')
# C:\Users\being\AppData\Local\Programs\Python\Python312\Lib\site-packages\bar_chart_race\_make_chart.py:286: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(self.df_values.columns)
# C:\Users\being\AppData\Local\Programs\Python\Python312\Lib\site-packages\bar_chart_race\_make_chart.py:287: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
# ---------------------------------------------------------------------------
# ...
