# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('AAPL.csv', index_col='date', parse_dates=['date'])
df
# Out:
#                            Unnamed: 0 symbol    close     high       low  \
# date
# 2015-05-27 00:00:00+00:00           0   AAPL  132.045  132.260  130.0500
# 2015-05-28 00:00:00+00:00           1   AAPL  131.780  131.950  131.1000
# 2015-05-29 00:00:00+00:00           2   AAPL  130.280  131.450  129.9000
# 2015-06-01 00:00:00+00:00           3   AAPL  130.535  131.390  130.0500
# 2015-06-02 00:00:00+00:00           4   AAPL  129.960  130.655  129.3200
# ...                               ...    ...      ...      ...       ...
# 2020-05-18 00:00:00+00:00        1253   AAPL  314.960  316.500  310.3241
# 2020-05-19 00:00:00+00:00        1254   AAPL  313.140  318.520  313.0100
# 2020-05-20 00:00:00+00:00        1255   AAPL  319.230  319.520  316.2000
# 2020-05-21 00:00:00+00:00        1256   AAPL  316.850  320.890  315.8700
# 2020-05-22 00:00:00+00:00        1257   AAPL  318.890  319.230  315.3500
#
#                              open    volume    adjClose     adjHigh  \
# date
# ...

# %%
df.plot()
# Out:
# <Axes: xlabel='date'>

# %%
df.loc['2016-05'].plot()
plt.title('Stocks')
plt.legend(loc='best')
plt.xlabel('Years')
plt.ylabel('Price')
plt.grid()

# %%
df.plot(y='close', c='r', linewidth=3)
# Out:
# <Axes: xlabel='date'>

# %%
df.plot(y=['close', 'open'])
# Out:
# <Axes: xlabel='date'>

# %%
df.plot(subplots=True)
# Out:
# array([<Axes: xlabel='date'>, <Axes: xlabel='date'>,
#        <Axes: xlabel='date'>, <Axes: xlabel='date'>,
#        <Axes: xlabel='date'>, <Axes: xlabel='date'>,
#        <Axes: xlabel='date'>, <Axes: xlabel='date'>,
#        <Axes: xlabel='date'>, <Axes: xlabel='date'>,
#        <Axes: xlabel='date'>, <Axes: xlabel='date'>,
#        <Axes: xlabel='date'>], dtype=object)

# %%
df.plot(subplots=True, figsize=(15,10))
# Out:
# array([<Axes: xlabel='date'>, <Axes: xlabel='date'>,
#        <Axes: xlabel='date'>, <Axes: xlabel='date'>,
#        <Axes: xlabel='date'>, <Axes: xlabel='date'>,
#        <Axes: xlabel='date'>, <Axes: xlabel='date'>,
#        <Axes: xlabel='date'>, <Axes: xlabel='date'>,
#        <Axes: xlabel='date'>, <Axes: xlabel='date'>,
#        <Axes: xlabel='date'>], dtype=object)

# %%
df.index = df.index.year
df
# Out:
#       Unnamed: 0 symbol    close     high       low    open    volume  \
# date
# 2015           0   AAPL  132.045  132.260  130.0500  130.34  45833246
# 2015           1   AAPL  131.780  131.950  131.1000  131.86  30733309
# 2015           2   AAPL  130.280  131.450  129.9000  131.23  50884452
# 2015           3   AAPL  130.535  131.390  130.0500  131.20  32112797
# 2015           4   AAPL  129.960  130.655  129.3200  129.86  33667627
# ...          ...    ...      ...      ...       ...     ...       ...
# 2020        1253   AAPL  314.960  316.500  310.3241  313.17  33843125
# 2020        1254   AAPL  313.140  318.520  313.0100  315.03  25432385
# 2020        1255   AAPL  319.230  319.520  316.2000  316.68  27876215
# 2020        1256   AAPL  316.850  320.890  315.8700  318.66  25672211
# 2020        1257   AAPL  318.890  319.230  315.3500  315.77  20450754
#
#         adjClose     adjHigh      adjLow     adjOpen  adjVolume  divCash  \
# date
# ...

# %%
df.plot(y='high', kind='bar')
# Out:
# <Axes: xlabel='date'>

# %%
df.plot(y='high', kind='barh')
# Out:
# <Axes: ylabel='date'>
