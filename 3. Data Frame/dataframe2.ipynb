# %%
import pandas as pd

# %%
df = pd.read_csv('imdb-top-1000.csv')
df
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %%
df.describe().round()
# Out:
#        IMDB_Rating  Meta_score  No_of_Votes
# count       1000.0       843.0       1000.0
# mean           8.0        78.0     273693.0
# std            0.0        12.0     327373.0
# min            8.0        28.0      25088.0
# 25%            8.0        70.0      55526.0
# 50%            8.0        79.0     138548.0
# 75%            8.0        87.0     374161.0
# max            9.0       100.0    2343110.0

# %%
df['Gross'] = df['Gross'].str.replace(',', '') # replace , with empty value
df['Gross']
# Out:
# 0       28341469
# 1      134966411
# 2      534858444
# 3       57300000
# 4        4360000
#          ...
# 995          NaN
# 996          NaN
# 997     30500000
# 998          NaN
# 999          NaN
# Name: Gross, Length: 1000, dtype: object

# %%
df['Gross'] = df['Gross'].fillna(0).astype('int64') # nan avlue to 0 and convert to int64

# %%
df.describe().round()
# Out:
#        IMDB_Rating  Meta_score  No_of_Votes        Gross
# count       1000.0       843.0       1000.0       1000.0
# mean           8.0        78.0     273693.0   56536878.0
# std            0.0        12.0     327373.0  103238179.0
# min            8.0        28.0      25088.0          0.0
# 25%            8.0        70.0      55526.0     445710.0
# 50%            8.0        79.0     138548.0   10702752.0
# 75%            8.0        87.0     374161.0   61539891.0
# max            9.0       100.0    2343110.0  936662225.0

# %%
df.describe().round()
# Out:
#        IMDB_Rating  Meta_score  No_of_Votes        Gross
# count       1000.0       843.0       1000.0       1000.0
# mean           8.0        78.0     273693.0   56536878.0
# std            0.0        12.0     327373.0  103238179.0
# min            8.0        28.0      25088.0          0.0
# 25%            8.0        70.0      55526.0     445710.0
# 50%            8.0        79.0     138548.0   10702752.0
# 75%            8.0        87.0     374161.0   61539891.0
# max            9.0       100.0    2343110.0  936662225.0

# %%
# similar to df.sort_values(coulumns, ascending=False).head(n)
df.nlargest(n=10, columns=['IMDB_Rating', 'Meta_score'])
# Out:
#                                           Poster_Link  \
# 0   https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1   https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 4   https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 3   https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 2   https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 5   https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 6   https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 7   https://m.media-amazon.com/images/M/MV5BNDE4OT...
# 10  https://m.media-amazon.com/images/M/MV5BN2EyZj...
# 12  https://m.media-amazon.com/images/M/MV5BOTQ5ND...
#
#                                          Series_Title Released_Year  \
# 0                            The Shawshank Redemption          1994
# 1                                       The Godfather          1972
# 4                                        12 Angry Men          1957
# 3                              The Godfather: Part II          1974
# ...

# %%
df.nsmallest(n=10, columns=['IMDB_Rating'], keep='first')
# Out:
#                                            Poster_Link  \
# 877  https://m.media-amazon.com/images/M/MV5BODQ0M2...
# 878  https://m.media-amazon.com/images/M/MV5BMjIwOT...
# 879  https://m.media-amazon.com/images/M/MV5BOTg4ZT...
# 880  https://m.media-amazon.com/images/M/MV5BNzk2Nm...
# 881  https://m.media-amazon.com/images/M/MV5BMjg4Zm...
# 882  https://m.media-amazon.com/images/M/MV5BYmM4Yz...
# 883  https://m.media-amazon.com/images/M/MV5BMjQ2ND...
# 884  https://m.media-amazon.com/images/M/MV5BOWVmZG...
# 885  https://m.media-amazon.com/images/M/MV5BMTc5Nz...
# 886  https://m.media-amazon.com/images/M/MV5BMTkwOD...
#
#                          Series_Title Released_Year Certificate  Runtime  \
# 877                       Dark Waters          2019       PG-13  126 min
# 878                         Searching          2018         U/A  102 min
# 879  Once Upon a Time... in Hollywood          2019           A  161 min
# ...

# %%
df.nsmallest(n=10, columns=['IMDB_Rating'], keep='first')
# Out:
#                                            Poster_Link  \
# 877  https://m.media-amazon.com/images/M/MV5BODQ0M2...
# 878  https://m.media-amazon.com/images/M/MV5BMjIwOT...
# 879  https://m.media-amazon.com/images/M/MV5BOTg4ZT...
# 880  https://m.media-amazon.com/images/M/MV5BNzk2Nm...
# 881  https://m.media-amazon.com/images/M/MV5BMjg4Zm...
# 882  https://m.media-amazon.com/images/M/MV5BYmM4Yz...
# 883  https://m.media-amazon.com/images/M/MV5BMjQ2ND...
# 884  https://m.media-amazon.com/images/M/MV5BOWVmZG...
# 885  https://m.media-amazon.com/images/M/MV5BMTc5Nz...
# 886  https://m.media-amazon.com/images/M/MV5BMTkwOD...
#
#                          Series_Title Released_Year Certificate  Runtime  \
# 877                       Dark Waters          2019       PG-13  126 min
# 878                         Searching          2018         U/A  102 min
# 879  Once Upon a Time... in Hollywood          2019           A  161 min
# ...

# %%
df.nsmallest(n=10, columns=['IMDB_Rating'], keep='first')
# Out:
#                                            Poster_Link  \
# 877  https://m.media-amazon.com/images/M/MV5BODQ0M2...
# 878  https://m.media-amazon.com/images/M/MV5BMjIwOT...
# 879  https://m.media-amazon.com/images/M/MV5BOTg4ZT...
# 880  https://m.media-amazon.com/images/M/MV5BNzk2Nm...
# 881  https://m.media-amazon.com/images/M/MV5BMjg4Zm...
# 882  https://m.media-amazon.com/images/M/MV5BYmM4Yz...
# 883  https://m.media-amazon.com/images/M/MV5BMjQ2ND...
# 884  https://m.media-amazon.com/images/M/MV5BOWVmZG...
# 885  https://m.media-amazon.com/images/M/MV5BMTc5Nz...
# 886  https://m.media-amazon.com/images/M/MV5BMTkwOD...
#
#                          Series_Title Released_Year Certificate  Runtime  \
# 877                       Dark Waters          2019       PG-13  126 min
# 878                         Searching          2018         U/A  102 min
# 879  Once Upon a Time... in Hollywood          2019           A  161 min
# ...

# %%
df.set_index('Series_Title', drop=False)
# Out:
#                                                                 Poster_Link  \
# Series_Title
# The Shawshank Redemption  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# The Godfather             https://m.media-amazon.com/images/M/MV5BM2MyNj...
# The Dark Knight           https://m.media-amazon.com/images/M/MV5BMTMxNT...
# The Godfather: Part II    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 12 Angry Men              https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ...                                                                     ...
# Breakfast at Tiffany's    https://m.media-amazon.com/images/M/MV5BNGEwMT...
# Giant                     https://m.media-amazon.com/images/M/MV5BODk3Yj...
# From Here to Eternity     https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# Lifeboat                  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# The 39 Steps              https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
# ...

# %%
df.reset_index(drop=True)
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
df.drop(columns=['Certificate', 'Poster_Link'])
# Out:
#                  Series_Title Released_Year  Runtime  \
# 0    The Shawshank Redemption          1994  142 min
# 1               The Godfather          1972  175 min
# 2             The Dark Knight          2008  152 min
# 3      The Godfather: Part II          1974  202 min
# 4                12 Angry Men          1957   96 min
# ..                        ...           ...      ...
# 995    Breakfast at Tiffany's          1961  115 min
# 996                     Giant          1956  201 min
# 997     From Here to Eternity          1953  118 min
# 998                  Lifeboat          1944   97 min
# 999              The 39 Steps          1935   86 min
#
#                         Genre  IMDB_Rating  \
# 0                       Drama          9.3
# 1                Crime, Drama          9.2
# 2        Action, Crime, Drama          9.0
# 3                Crime, Drama          9.0
# 4                Crime, Drama          9.0
# ..                        ...          ...
# ...

# %%
df.drop(labels=[1,2,3])
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 5    https://m.media-amazon.com/images/M/MV5BNzA5ZD...
# 6    https://m.media-amazon.com/images/M/MV5BNGNhMD...
# 7    https://m.media-amazon.com/images/M/MV5BNDE4OT...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                                       Series_Title Released_Year Certificate  \
# 0                         The Shawshank Redemption          1994           A
# 4                                     12 Angry Men          1957           U
# ...

# %%
df.drop([0,5,6])
# Out:
#                                            Poster_Link  \
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# 7    https://m.media-amazon.com/images/M/MV5BNDE4OT...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# ...

# %%
# Adding column
df['watched'] = False
df
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
# adding coulmn at specific location
df.insert(loc=2, column='my_rating', value=None)
df
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title my_rating Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption      None          1994           A  142 min
# 1               The Godfather      None          1972           A  175 min
# 2             The Dark Knight      None          2008          UA  152 min
# ...

# %%
# drop every row with NaN
df.dropna()
# Out:
# Empty DataFrame
# Columns: [Poster_Link, Series_Title, my_rating, Released_Year, Certificate, Runtime, Genre, IMDB_Rating, Overview, Meta_score, Director, Star1, Star2, Star3, Star4, No_of_Votes, Gross, watched]
# Index: []

# %%
# remove column with NaN
df.dropna(axis=1)
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year  Runtime  \
# 0    The Shawshank Redemption          1994  142 min
# 1               The Godfather          1972  175 min
# 2             The Dark Knight          2008  152 min
# 3      The Godfather: Part II          1974  202 min
# ...
