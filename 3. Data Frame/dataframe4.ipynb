# %%
import pandas as pd

# %%
t = pd.read_excel('titanic3.xls', index_col='name')
t
# Out:
#                                                  pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                         1         1  female
# Allison, Master. Hudson Trevor                        1         1    male
# Allison, Miss. Helen Loraine                          1         0  female
# Allison, Mr. Hudson Joshua Creighton                  1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1         0  female
# ...                                                 ...       ...     ...
# Zabour, Miss. Hileni                                  3         0  female
# Zabour, Miss. Thamine                                 3         0  female
# Zakarian, Mr. Mapriededer                             3         0    male
# Zakarian, Mr. Ortin                                   3         0    male
# Zimmerman, Mr. Leo                                    3         0    male
#
#                                                      age  sibsp  parch  \
# ...

# %%
t.sort_index()
# Out:
#                                                pclass  survived     sex   age  \
# name
# Abbing, Mr. Anthony                                 3         0    male  42.0
# Abbott, Master. Eugene Joseph                       3         0    male  13.0
# Abbott, Mr. Rossmore Edward                         3         0    male  16.0
# Abbott, Mrs. Stanton (Rosa Hunt)                    3         1  female  35.0
# Abelseth, Miss. Karen Marie                         3         1  female  16.0
# ...                                               ...       ...     ...   ...
# del Carlo, Mrs. Sebastiano (Argenia Genovesi)       2         1  female  24.0
# van Billiard, Master. James William                 3         0    male   NaN
# van Billiard, Master. Walter John                   3         0    male  11.5
# van Billiard, Mr. Austin Blyler                     3         0    male  40.5
# van Melkebeke, Mr. Philemon                         3         0    male   NaN
#
# ...

# %%
t.loc['Zabour, Miss. Hileni']
# Out:
# pclass             3
# survived           0
# sex           female
# age             14.5
# sibsp              1
# parch              0
# ticket          2665
# fare         14.4542
# cabin            NaN
# embarked           C
# boat             NaN
# body           328.0
# home.dest        NaN
# Name: Zabour, Miss. Hileni, dtype: object

# %%
t.loc[['Abbing, Mr. Anthony', 'Zabour, Miss. Hileni']]
# Out:
#                       pclass  survived     sex   age  sibsp  parch     ticket  \
# name
# Abbing, Mr. Anthony        3         0    male  42.0      0      0  C.A. 5547
# Zabour, Miss. Hileni       3         0  female  14.5      1      0       2665
#
#                          fare cabin embarked boat   body home.dest
# name
# Abbing, Mr. Anthony    7.5500   NaN        S  NaN    NaN       NaN
# Zabour, Miss. Hileni  14.4542   NaN        C  NaN  328.0       NaN

# %%
t.loc['Abbing, Mr. Anthony':'Zabour, Miss. Hileni']
# Out:
#                                          pclass  survived     sex   age  \
# name
# Abbing, Mr. Anthony                           3         0    male  42.0
# Abbott, Master. Eugene Joseph                 3         0    male  13.0
# Abbott, Mr. Rossmore Edward                   3         0    male  16.0
# Abbott, Mrs. Stanton (Rosa Hunt)              3         1  female  35.0
# Abelseth, Miss. Karen Marie                   3         1  female  16.0
# ...                                         ...       ...     ...   ...
# Yasbeck, Mrs. Antoni (Selini Alexander)       3         1  female  15.0
# Youseff, Mr. Gerious                          3         0    male  45.5
# Yousif, Mr. Wazli                             3         0    male   NaN
# Yousseff, Mr. Gerious                         3         0    male   NaN
# Zabour, Miss. Hileni                          3         0  female  14.5
#
#                                          sibsp  parch     ticket     fare  \
# name
# ...

# %%
# return series od names with specidied column
t.loc['Zabour, Miss. Hileni', ['fare', 'sex']]
# Out:
# fare    14.4542
# sex      female
# Name: Zabour, Miss. Hileni, dtype: object

# %%
# indexed based location rows
t.iloc[[0,3,7]]
# Out:
#                                       pclass  survived     sex   age  sibsp  \
# name
# Allen, Miss. Elisabeth Walton              1         1  female  29.0      0
# Allison, Mr. Hudson Joshua Creighton       1         0    male  30.0      1
# Andrews, Mr. Thomas Jr                     1         0    male  39.0      0
#
#                                       parch  ticket      fare    cabin  \
# name
# Allen, Miss. Elisabeth Walton             0   24160  211.3375       B5
# Allison, Mr. Hudson Joshua Creighton      2  113781  151.5500  C22 C26
# Andrews, Mr. Thomas Jr                    0  112050    0.0000      A36
#
#                                      embarked boat   body  \
# name
# Allen, Miss. Elisabeth Walton               S    2    NaN
# Allison, Mr. Hudson Joshua Creighton        S  NaN  135.0
# Andrews, Mr. Thomas Jr                      S  NaN    NaN
#
#                                                             home.dest
# name
# ...

# %%
# show rows of column 2
t.iloc[[1,2,3,4,8], 2]
# Out:
# name
# Allison, Master. Hudson Trevor                       male
# Allison, Miss. Helen Loraine                       female
# Allison, Mr. Hudson Joshua Creighton                 male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    female
# Appleton, Mrs. Edward Dale (Charlotte Lamson)      female
# Name: sex, dtype: object

# %%
# Broadcasting
# concept from numpy
# performs arithmetic operation between arrays or dataframe or series
data1 = pd.Series([1,2,3,4,5])
data2 = pd.Series([1,2,3,4,5])
data1 + data2
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# dtype: int64

# %%
data3 = pd.Series([1,2,3,4,5,6,7])
data1 + data3
# Out:
# 0     2.0
# 1     4.0
# 2     6.0
# 3     8.0
# 4    10.0
# 5     NaN
# 6     NaN
# dtype: float64

# %%
# conditions
male = t['sex'] == 'male'
t[male]
# Out:
#                                       pclass  survived   sex      age  sibsp  \
# name
# Allison, Master. Hudson Trevor             1         1  male   0.9167      1
# Allison, Mr. Hudson Joshua Creighton       1         0  male  30.0000      1
# Anderson, Mr. Harry                        1         1  male  48.0000      0
# Andrews, Mr. Thomas Jr                     1         0  male  39.0000      0
# Artagaveytia, Mr. Ramon                    1         0  male  71.0000      0
# ...                                      ...       ...   ...      ...    ...
# Yousif, Mr. Wazli                          3         0  male      NaN      0
# Yousseff, Mr. Gerious                      3         0  male      NaN      0
# Zakarian, Mr. Mapriededer                  3         0  male  26.5000      0
# Zakarian, Mr. Ortin                        3         0  male  27.0000      0
# Zimmerman, Mr. Leo                         3         0  male  29.0000      0
#
# ...

# %%
t[t['age'] > 5]
# Out:
#                                                  pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                         1         1  female
# Allison, Mr. Hudson Joshua Creighton                  1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1         0  female
# Anderson, Mr. Harry                                   1         1    male
# Andrews, Miss. Kornelia Theodosia                     1         1  female
# ...                                                 ...       ...     ...
# Youseff, Mr. Gerious                                  3         0    male
# Zabour, Miss. Hileni                                  3         0  female
# Zakarian, Mr. Mapriededer                             3         0    male
# Zakarian, Mr. Ortin                                   3         0    male
# Zimmerman, Mr. Leo                                    3         0    male
#
# ...

# %%
# bit wise operation & | ~
(t['sex'] == 'male') & (t['age'] > 5)
# Out:
# name
# Allen, Miss. Elisabeth Walton                      False
# Allison, Master. Hudson Trevor                     False
# Allison, Miss. Helen Loraine                       False
# Allison, Mr. Hudson Joshua Creighton                True
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    False
#                                                    ...
# Zabour, Miss. Hileni                               False
# Zabour, Miss. Thamine                              False
# Zakarian, Mr. Mapriededer                           True
# Zakarian, Mr. Ortin                                 True
# Zimmerman, Mr. Leo                                  True
# Length: 1309, dtype: bool

# %%
#between
t1 = t['age'].between(20,25, inclusive='both')
t[t1]
# Out:
#                                                  pclass  survived     sex  \
# name
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1         0  female
# Aubart, Mme. Leontine Pauline                         1         1  female
# Baxter, Mr. Quigg Edmond                              1         0    male
# Birnbaum, Mr. Jakob                                   1         0    male
# Bishop, Mr. Dickinson H                               1         1    male
# ...                                                 ...       ...     ...
# Vendel, Mr. Olof Edvin                                3         0    male
# Vovk, Mr. Janko                                       3         0    male
# Waelens, Mr. Achille                                  3         0    male
# Wiklund, Mr. Karl Johan                               3         0    male
# Windelov, Mr. Einar                                   3         0    male
#
#                                                   age  sibsp  parch  \
# ...

# %%
t2 = t['pclass'].isin([1,2])
t[t2]
# Out:
#                                                  pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                         1         1  female
# Allison, Master. Hudson Trevor                        1         1    male
# Allison, Miss. Helen Loraine                          1         0  female
# Allison, Mr. Hudson Joshua Creighton                  1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1         0  female
# ...                                                 ...       ...     ...
# Wheeler, Mr. Edwin "Frederick"                        2         0    male
# Wilhelms, Mr. Charles                                 2         1    male
# Williams, Mr. Charles Eugene                          2         1    male
# Wright, Miss. Marion                                  2         1  female
# Yrois, Miss. Henriette ("Mrs Harbeck")                2         0  female
#
#                                                      age  sibsp  parch  \
# ...

# %%
t3 = t['pclass'].isnull()
t[t3]
# Out:
# Empty DataFrame
# Columns: [pclass, survived, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %%
t4 = t['pclass'].notnull()
t[t4]
# Out:
#                                                  pclass  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                         1         1  female
# Allison, Master. Hudson Trevor                        1         1    male
# Allison, Miss. Helen Loraine                          1         0  female
# Allison, Mr. Hudson Joshua Creighton                  1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1         0  female
# ...                                                 ...       ...     ...
# Zabour, Miss. Hileni                                  3         0  female
# Zabour, Miss. Thamine                                 3         0  female
# Zakarian, Mr. Mapriededer                             3         0    male
# Zakarian, Mr. Ortin                                   3         0    male
# Zimmerman, Mr. Leo                                    3         0    male
#
#                                                      age  sibsp  parch  \
# ...

# %%
# Renaming
t.columns
# Out:
# Index(['pclass', 'survived', 'sex', 'age', 'sibsp', 'parch', 'ticket', 'fare',
#        'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
t.columns[0]
# Out:
# 'pclass'

# %%
t.rename(columns={'pclass':'passenger'})
# Out:
#                                                  passenger  survived     sex  \
# name
# Allen, Miss. Elisabeth Walton                            1         1  female
# Allison, Master. Hudson Trevor                           1         1    male
# Allison, Miss. Helen Loraine                             1         0  female
# Allison, Mr. Hudson Joshua Creighton                     1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)          1         0  female
# ...                                                    ...       ...     ...
# Zabour, Miss. Hileni                                     3         0  female
# Zabour, Miss. Thamine                                    3         0  female
# Zakarian, Mr. Mapriededer                                3         0    male
# Zakarian, Mr. Ortin                                      3         0    male
# Zimmerman, Mr. Leo                                       3         0    male
#
# ...

# %%
t.rename(index={'Allen, Miss. Elisabeth Walton': 'Allen'})
# Out:
#                                                  pclass  survived     sex  \
# name
# Allen                                                 1         1  female
# Allison, Master. Hudson Trevor                        1         1    male
# Allison, Miss. Helen Loraine                          1         0  female
# Allison, Mr. Hudson Joshua Creighton                  1         0    male
# Allison, Mrs. Hudson J C (Bessie Waldo Daniels)       1         0  female
# ...                                                 ...       ...     ...
# Zabour, Miss. Hileni                                  3         0  female
# Zabour, Miss. Thamine                                 3         0  female
# Zakarian, Mr. Mapriededer                             3         0    male
# Zakarian, Mr. Ortin                                   3         0    male
# Zimmerman, Mr. Leo                                    3         0    male
#
#                                                      age  sibsp  parch  \
# ...
